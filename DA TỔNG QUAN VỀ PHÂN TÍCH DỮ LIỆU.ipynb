# %% [markdown]
# # <span style='color:blue;'>TỔNG QUAN VỀ PHÂN TÍCH DỮ LIỆU</span>
# > <span style='color:gray;'>***Data analysis course - 2022***</span>
# <hr>

# %% [markdown]
# ## Các thang đo
# > * **Thang đo danh nghĩa (nominal scale):** Trong thang đo này các con số chỉ dùng để phân loại các đối tượng, chúng không mang ý nghĩa nào khác. Về thực chất thang đo danh nghĩa là sự phân loại và đặt tên cho các biểu hiện và ấn định cho chúng một ký số tương ứng.
# >
# > Ví dụ: Vui lòng cho biết giới tính của anh/chị?
# > 1. Nam
# > 2. Nữ
# > Thang đo danh nghĩa giúp quy ước các cá nhân trả lời câu hỏi này thành các biểu hiện của biến “giới tính”. Chúng ta có thể quy ước đặt Nam = 1, Nữ = 2. Những con số này mang tính định danh vì chúng ta không thể cộng hoặc tính ra giá trị trung bình của “giới tính”.
# > Những phép toán thống kê có thể sử dụng được cho thang đo danh nghĩa gồm: đếm, tính tần suất của một biểu hiện, xác định giá trị mode, thực hiện một số phép kiểm định.
# >
# > * **Thang đo thứ bậc (ordinal scale):** là thang đo mà các con số ở thang đo danh nghĩa được sắp xếp theo một quy ước nào đó về thứ bậc hay sự hơn kém, nhưng ta không biết được khoảng cách giữa chúng. Điều này có nghĩa là bất cứ thang đo thứ bậc nào cũng là thang đo danh nghĩa nhưng không thể suy ngược lại.
# >
# > Ví dụ: Vui lòng cho biết trình độ học vấn cao nhất của anh/chị?
# >
# > 1. Dưới trung học phổ thông
# > 2. Trung cấp, cao đẳng
# > 3. Đại học
# > 4. Sau đại học
# > Với câu hỏi này chúng ta có thể quy ước các cá nhân trả lời theo bốn biểu hiện của biến “trình độ học vấn”. Một người có câu trả lời được mã hóa bởi số 3 sẽ có trình độ học vấn cao hơn người mang số 2 hoặc 1
# > Đối với thang đo thứ bậc, khuynh hướng trung tâm có thể xem xét bằng số trung vị và số mode, độ phân tán chỉ đo được bằng khoảng biến thiên và khoảng tứ phân vị
# >
# > * **Thang đo khoảng (interval scale):** Là một dạng đặc biệt của thang đo thứ bậc vì nó cho biết khoảng cách giữa các thứ bậc. Thông thường thang đo khoảng có dạng là một dãy các chữ số liên tục và đều đặn từ 1 đến 5, từ 1 đến 7 hoặc từ 1 đến 10. Dãy số này có 2 cực ở hai đầu thể hiện 2 trạng thái đối nghịch nhau, chẳng hạn như 1 là rất ghét, 7 là rất thích; 1 là không đồng ý, 7 là rất đồng ý; 1 là rất không hài lòng, 7 là rất hài lòng... Những phép toán thống kê có thể sử dụng thêm cho loại thang đo này so với 2 loại thang đo trước là tính khoảng biến thiên, số trung bình, độ lệch chuẩn.
# >
# > Ví dụ: Anh/chị vui lòng đánh giá tầm quan trọng của các yếu tố sau đây đối với cuộc sống của một người? (1=không quan trọng; 7=rất quan trọng)
# >
# > * **Thanh đo tỉ lệ (ratio scale):** thang đo tỉ lệ có tất cả các đặc tính khoảng cách và thứ tự của thang đo khoảng, điểm 0 trong thang đo tỉ lệ là một trị số thật nên ta có thể thực hiện được phép chia để tính tỉ lệ nhằm mục đích so sánh. Thang đo tỉ lệ cho phép thực hiện mọi phép toán phân tích thống kê.
# >
# > Ví dụ: Anh/chị vui lòng cho biết thu nhập hàng tháng của mình (triệu đồng)? Các con số thu được từ câu hỏi nêu trên có thể tính tỉ lệ được (chẳng hạn một người có thu nhập 30 triệu thì nhiều gấp đôi người có thu nhập 15 triệu.
# > ![interval.JPG](interval.JPG)

# %% [markdown]
# ## I. Thực hành trên bộ dữ liệu covid 19

# %% [markdown]
# ### 1. Đọc dữ liệu
# > * Sử dụng thư viện pandas để làm việc với dữ liệu dạng bảng
# > * Đọc dữ liệu từ file với encoding = 'UTF-8'
# > * Hiển thị dữ liệu đọc được để quan sát

# %%
pwd

# %%
# sử dụng thư viện pandas để làm việc với dữ liệu dạng bảng
import pandas as pd


# đọc dữ liệu, file dữ liệu thường có encoding = 'UTF-8' hoặc 'ISO-8859-1'
data=pd.read_csv('resources\subset-covid-data.csv', encoding= 'UTF-8')

# hiển thị 5 dòng dữ liệu đầu tiên
data
# Out:
#          country continent        date  day  month  year  cases  deaths  \
# 0    Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1        Albania    Europe  2020-04-12   12      4  2020     17       0
# 2        Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3        Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4         Angola    Africa  2020-04-12   12      4  2020      0       0
# ..           ...       ...         ...  ...    ...   ...    ...     ...
# 201    Venezuela   America  2020-04-12   12      4  2020      0       0
# 202      Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203        Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204       Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205     Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 0            AFG  37172386.0
# 1            ALB   2866376.0
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.head()
# Out:
#        country continent        date  day  month  year  cases  deaths  \
# 0  Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1      Albania    Europe  2020-04-12   12      4  2020     17       0
# 2      Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3      Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4       Angola    Africa  2020-04-12   12      4  2020      0       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# 2          DZA  42228429.0
# 3          AND     77006.0
# 4          AGO  30809762.0

# %%
data.head(10)
# Out:
#                country continent        date  day  month  year  cases  deaths  \
# 0          Afghanistan      Asia  2020-04-12   12      4  2020     34       3
# 1              Albania    Europe  2020-04-12   12      4  2020     17       0
# 2              Algeria    Africa  2020-04-12   12      4  2020     64      19
# 3              Andorra    Europe  2020-04-12   12      4  2020     21       2
# 4               Angola    Africa  2020-04-12   12      4  2020      0       0
# 5             Anguilla   America  2020-04-12   12      4  2020      0       0
# 6  Antigua_and_Barbuda   America  2020-04-12   12      4  2020      0       0
# 7            Argentina   America  2020-04-12   12      4  2020    162       7
# 8              Armenia    Europe  2020-04-12   12      4  2020     30       2
# 9                Aruba   America  2020-04-12   12      4  2020      6       0
#
#   country_code  population
# 0          AFG  37172386.0
# 1          ALB   2866376.0
# ...

# %%
data.tail(6)
# Out:
#         country continent        date  day  month  year  cases  deaths  \
# 200  Uzbekistan      Asia  2020-04-12   12      4  2020    172       1
# 201   Venezuela   America  2020-04-12   12      4  2020      0       0
# 202     Vietnam      Asia  2020-04-12   12      4  2020      4       0
# 203       Yemen      Asia  2020-04-12   12      4  2020      0       0
# 204      Zambia    Africa  2020-04-12   12      4  2020      0       0
# 205    Zimbabwe    Africa  2020-04-12   12      4  2020      3       0
#
#     country_code  population
# 200          UZB  32955400.0
# 201          VEN  28870195.0
# 202          VNM  95540395.0
# 203          YEM  28498687.0
# 204          ZMB  17351822.0
# 205          ZWE  14439018.0

# %% [markdown]
# ### 2. Tìm hiểu cấu trúc bộ dữ liệu
# > * Xem số dòng và số cột của bộ dữ liệu với hàm `info()`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       206 non-null    object
#  1   continent     206 non-null    object
#  2   date          206 non-null    object
#  3   day           206 non-null    int64
#  4   month         206 non-null    int64
#  5   year          206 non-null    int64
#  6   cases         206 non-null    int64
#  7   deaths        206 non-null    int64
#  8   country_code  202 non-null    object
#  9   population    202 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 16.2+ KB

# %%
data.describe()
# Out:
#               day       month    year         cases       deaths    population
# count  206.000000  206.000000   206.0    206.000000   206.000000  2.020000e+02
# mean    12.024272    3.985437  2020.0    395.247573    29.713592  3.731716e+07
# std      0.424141    0.209020     0.0   2160.176439   159.533131  1.413776e+08
# min     11.000000    1.000000  2020.0      0.000000     0.000000  1.000000e+03
# 25%     12.000000    4.000000  2020.0      0.000000     0.000000  1.278222e+06
# 50%     12.000000    4.000000  2020.0     11.500000     0.000000  7.042862e+06
# 75%     12.000000    4.000000  2020.0     88.750000     3.000000  2.600084e+07
# max     18.000000    4.000000  2020.0  28391.000000  1831.000000  1.392730e+09

# %%
data.country_code.describe()
# Out:
# count     202
# unique    202
# top       AFG
# freq        1
# Name: country_code, dtype: object

# %% [markdown]
# ### 3. Giải đáp các thắc mắc
# > * Dữ liệu được thống kê cho những ngày nào?
# > * Các quốc gia có số lượng ca mắc mới, số ca tử vong trong ngày 12-4-2020 có giống nhau không?
# > * Tổng số ca mắc mới, số ca tử vong ở từng châu lục
# > * Top 5 quốc gia có số ca nhiễm mới cao nhất
# > * Top 5 quốc gia có số ca tử vong cao nhất

# %% [markdown]
# ___Dữ liệu được thống kê cho những ngày nào?___

# %%
data.date.value_counts()
# Out:
# 2020-04-12    204
# 2020-01-18      1
# 2020-04-11      1
# Name: date, dtype: int64

# %% [markdown]
# ___Các quốc gia có số lượng ca mắc mới, số ca tử vong trong ngày 12-4-2020 có giống nhau không?___

# %%
cleaned_data = data[data.date == '2020-04-12']
# Vẽ biểu đồ phân bố số lượng ca mắc mới ở các quốc gia
print ("trung bình số ca mắc mới: " + str(cleaned_data.cases.mean()))
print ("trung vị của số ca mắc mới: "+ str(cleaned_data.cases.median()))
import matplotlib.pyplot as plt
plt.hist(cleaned_data.cases, bins = 40)
plt.title("Phân bố số ca mắc mới")
plt.xlabel("số số ca mắc mới")
plt.ylabel("Số lượng quốc gia")
# Out:
# trung bình số ca mắc mới: 376.8186274509804
# trung vị của số ca mắc mới: 11.5
# Text(0, 0.5, 'Số lượng quốc gia')

# %% [markdown]
# ___Tổng số ca mắc mới, số ca tử vong ở từng châu lục___

# %%
print("tổng số ca nhiễm và số ca tử vong của các châu lục")
cleaned_data.groupby('continent')[['cases','deaths']].sum()
# Out:
# tổng số ca nhiễm và số ca tử vong của các châu lục
#            cases  deaths
# continent
# Africa       714      52
# America    33519    2111
# Asia       12979     383
# Europe     29591    2966
# Oceania       68       4

# %% [markdown]
# ___Top 5 quốc gia có số ca nhiễm mới cao nhất___

# %%
print ("5 quốc gia có số ca nhiễm mới cao nhất")
data = data.sort_values('cases',ascending = False)
data.head(5)
# Out:
# 5 quốc gia có số ca nhiễm mới cao nhất
#                       country continent        date  day  month  year  cases  \
# 198  United_States_of_America   America  2020-04-12   12      4  2020  28391
# 195            United_Kingdom    Europe  2020-04-12   12      4  2020   8719
# 190                    Turkey      Asia  2020-04-12   12      4  2020   5138
# 98                      Italy    Europe  2020-04-12   12      4  2020   4694
# 177                     Spain    Europe  2020-04-11   11      4  2020   4550
#
#      deaths country_code   population
# 198    1831          USA  327167434.0
# 195     839          GBR   66488991.0
# 190      95          TUR   82319724.0
# 98      619          ITA   60431283.0
# 177     605          ESP   46723749.0

# %% [markdown]
# ___Top 5 quốc gia có số ca tử vong cao nhất___

# %%
print ("5 quốc gia có số ca tử vong cao nhất")
data = data.sort_values('deaths',ascending = False)
data.head(5)
# Out:
# 5 quốc gia có số ca tử vong cao nhất
#                       country continent        date  day  month  year  cases  \
# 198  United_States_of_America   America  2020-04-12   12      4  2020  28391
# 195            United_Kingdom    Europe  2020-04-12   12      4  2020   8719
# 69                     France    Europe  2020-04-12   12      4  2020   3114
# 98                      Italy    Europe  2020-04-12   12      4  2020   4694
# 177                     Spain    Europe  2020-04-11   11      4  2020   4550
#
#      deaths country_code   population
# 198    1831          USA  327167434.0
# 195     839          GBR   66488991.0
# 69      635          FRA   66987244.0
# 98      619          ITA   60431283.0
# 177     605          ESP   46723749.0

# %%
data.tail(5)
# Out:
#                       country continent        date  day  month  year  cases  \
# 99                    Jamaica   America  2020-04-12   12      4  2020      4
# 13                    Bahamas   America  2020-04-12   12      4  2020      4
# 72                     Gambia    Africa  2020-04-12   12      4  2020      5
# 85                     Guyana   America  2020-04-12   12      4  2020      5
# 142  Northern_Mariana_Islands   Oceania  2020-04-12   12      4  2020      0
#
#      deaths country_code  population
# 99        0          JAM   2934855.0
# 13        0          BHS    385640.0
# 72        0          GMB   2280102.0
# 85        0          GUY    779004.0
# 142       0          MNP     56882.0

# %% [markdown]
# ## II. Thực hành trên bộ dữ liệu Online Retail

# %% [markdown]
# > **Mô tả bài toán**
# > Một công ty bán hàng online tại UK cần đánh giá tính hình kinh doanh của họ, bộ dữ liệu được đưa cho người phân tích gồm các thông tin sau:
# > * InvoiceNo: Số hóa đơn
# > * StockCode: mã hàng
# > * Description: Mô tả hàng
# > * Quantity: Số lượng
# > * InvoiceDate: Ngày bán
# > * UnitPrice: Đơn giá
# > * CustomerID: Mã khách hàng
# > * Country: Nước sản xuất

# %% [markdown]
# ### 1. Đọc dữ liệu

# %%
import pandas as pd
data=pd.read_csv('resources\OnlineRetail.csv', encoding = "ISO-8859-1")
# hiển thị 5 dòng dữ liệu đầu tiên
data.head()

# %% [markdown]
# ### 2. Tìm hiểu cấu trúc bộ dữ liệu

# %%
data.info()

# %% [markdown]
# ### 3. Giải đáp các thắc mắc
# > * Công ty bán hàng tại bao nhiêu quốc gia?
# > * Số lượng đơn hàng bán ra và tổng doanh thu?
# > * Top 10 mặt hàng có số lượng bán ra lớn nhất?
# > * Top 10 mặt hàng có doanh thu tốt nhất?

# %% [markdown]
# ___Công ty bán hàng tại bao nhiêu quốc gia?___

# %%
# lấy ra tên các quốc gia
country = data.Country.unique()
print ("số lượng các quốc gia: " + str(country.size))
print(country)

# %% [markdown]
# ___Số lượng đơn hàng bán ra và tổng doanh thu?___

# %%
# Tạo cột tính thành tiền của các mặt hàng
data['total'] = data['Quantity'] * data['UnitPrice'] 

# Giá trị đơn hàng của mỗi đơn hàng
total_invoices = data['total'].sum()
print ("số lượng hóa đơn bán ra: "+ str (data['InvoiceNo'].count()))
print ("Tổng doanh thu: " + str(total_invoices.sum()))

# %% [markdown]
# ___Top 10 mặt hàng có số lượng bán ra lớn nhất?___

# %%
quantity_product = data.groupby(['StockCode'])['Quantity'].sum().sort_values(ascending= False)
quantity_product.head(10)

# %% [markdown]
# ___Top 10 mặt hàng có doanh thu tốt nhất?___

# %%
quantity_product = data.groupby(['StockCode', 'Description'])['total'].sum().sort_values(ascending= False)
quantity_product.head(10)

# %% [markdown]
# ## III. Phân tích dữ liệu GDP List

# %% [markdown]
# > **Mô tả bài toán**
# > Bộ dữ liệu GDP list chứa dữ liệu dự báo về GDP của một số quốc gia, các thông tin được thống kê bao gồm:
# > * Country: Tên quốc gia
# > * Continent: Tên châu lục
# > * GDP (millions of US$): GDP tính theo đơn vị triệu USD
